# %% [markdown]
# <a href="https://colab.research.google.com/github/Tcccgit/Alura.Plus/blob/main/Desafio_alunos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# alunos = int(input("Digite a quantidade de alunos: "))
# monitores = int(input("Digite a quantidade de monitores: "))
# convidados = int(input("Digite a quantidade de convidados: "))
#
#
# total_pessoas = alunos + monitores + convidados
# limite_ingressos = 100
# limite_convidados = 20
#
# print("\n--- Resultado ---")
#
#
# if convidados > limite_convidados:
#     print("❌ O número de convidados excede o limite de 20.")
# elif total_pessoas > limite_ingressos:
#     print(f"❌ O total de pessoas ({total_pessoas}) ultrapassa o limite de 100 ingressos.")
# else:
#     print(f"✅ Tudo certo! Total de pessoas: {total_pessoas}.")
#     print("O evento pode ocorrer normalmente.")
#
#
# print("\nObrigatório respeitar o limite de 20 convidados e 100 ingressos no total.")
